# %% [markdown]
# # The Adult Income dataset
#
# ## Description
#
# ### Title of dataset: adult.csv
#
# Sources:
#
# *Original owners of database - US Census Bureau
# *Donor of database - Ronny Kohavi and Barry Becker
# *Date received - 05/19/96
#
# Number of Instances
#
# *48842 instances, mix of continuous and discrete (train=32561, test=16281)
# *45222 if instances with unknown values are removed (train=30162, test=15060)
# *Split into train-test using MLC++ GenCVFiles (2/3, 1/3 random).
#
# Number of Attributes/Fearures/Columns
#
# *6 continuous, 8 nominal attributes.
#
# Attribute Information/Fearures/Columns
#
# *age: continuous.
# *workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# *fnlwgt: continuous.
# *education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# *education-num: continuous.
# *marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# *occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# *relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# *race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# *sex: Female, Male.
# *capital-gain: continuous.
# *capital-loss: continuous.
# *hours-per-week: continuous.
# *native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# *income: >50K, <=50K
# Missing Values:
#
#  7% rows have missing values.
#
#  ### Objective:
#  *the objection of the project id to perfoem am EDA on the adult dataset and to find ans treat the missing values and to show it in graph form.

# %%
import numpy as np
import pandas as pd

# %%
miss = ['?']
df=pd.read_csv('adult.csv',na_values = miss)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
print(df.shape)
# Out:
# (48842, 15)

# %%
df.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Length: 48842, dtype: bool

# %%
df=df.drop('fnlwgt', axis=1)

# %%
df.shape
# Out:
# (48842, 14)

# %%
df[df.isnull().sum(axis=1) >=3]
# Out:
#        age workclass     education  educational-num         marital-status  \
# 2160    28       NaN     Bachelors               13          Never-married
# 2323    50       NaN  Some-college               10     Married-civ-spouse
# 2584    47       NaN       Masters               14               Divorced
# 2612    27       NaN       HS-grad                9          Never-married
# 2774    27       NaN       HS-grad                9          Never-married
# 3074    23       NaN     Assoc-voc               11          Never-married
# 3671    24       NaN  Some-college               10          Never-married
# 3853    28       NaN  Some-college               10     Married-civ-spouse
# 5052    21       NaN  Some-college               10          Never-married
# 5972    40       NaN     Assoc-voc               11              Separated
# 6800    22       NaN  Some-college               10          Never-married
# ...

# %%
df=df.dropna(how='any')
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# age                0.0
# workclass          0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %%
df
# Out:
#        age     workclass     education  educational-num      marital-status  \
# 0       25       Private          11th                7       Never-married
# 1       38       Private       HS-grad                9  Married-civ-spouse
# 2       28     Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3       44       Private  Some-college               10  Married-civ-spouse
# 5       34       Private          10th                6       Never-married
# ...    ...           ...           ...              ...                 ...
# 48837   27       Private    Assoc-acdm               12  Married-civ-spouse
# 48838   40       Private       HS-grad                9  Married-civ-spouse
# 48839   58       Private       HS-grad                9             Widowed
# 48840   22       Private       HS-grad                9       Never-married
# 48841   52  Self-emp-inc       HS-grad                9  Married-civ-spouse
#
# ...

# %%
100*(1-len(df.index)/48842)
# Out:
# 7.411653904426519

# %% [markdown]
# ### observation:
# the above percentage 7.41% is the percent on rows which have been deleted.

# %% [markdown]
# ## Univariate Analysis

# %%
import plotly as ply
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.subplot(1,2,1)
sns.distplot(df['age'])
plt.title('age')

plt.subplot(1,2,2)
sns.distplot(df['educational-num'])
plt.title('educational-num')
# Out:
# Text(0.5, 1.0, 'educational-num')

# %% [markdown]
# ### Observation:
# * In age graph most of the people are found to be between 35-45.
# * Age of the dataset is found to be in between 17-90.
#
# * In educational-num graph we can't see any symmetery.
# * Highest distribution is from somwhere 7-9.

# %%
plt.subplot(1,2,1)
sns.distplot(df['educational-num'])
plt.title('educational-num')

plt.subplot(1,2,2)
sns.distplot(df['hours-per-week'])
plt.title('hours-per-week')
# Out:
# Text(0.5, 1.0, 'hours-per-week')

# %% [markdown]
# ### Observation:
# * In educational-num there is no symmetery.
# * There is a gradual increase in and decrese in graph.
#
# * There is a large increase in the value from 25-50.

# %%
sns.boxplot(y='age',data=df)

# %% [markdown]
# ### Observation
# * The average age lies between 35
# * The min. age lies below 20.
# * The max. age lies above 70.
# * There is a outlier from 80-90.

# %%
sns.boxplot(y='educational-num',data=df)

# %% [markdown]
# ### Observation:
# * The average is 10.
# * The min is below 4 and max is 16.
# * The outlier lies below 2.

# %%
sns.boxplot(y='capital-gain',data=df)

# %% [markdown]
# ### Observation:
# * Most of the enteries are 0.

# %%
sns.boxplot(y='capital-loss',data=df)

# %% [markdown]
# ### Observation:
# * Most of the enteries are 0.

# %%
sns.boxplot(y='hours-per-week',data=df)

# %% [markdown]
# ### Observation:
# * The avegare work hour is between 40-42.
# * the lower work hour is 32.
# * the higher work is 50.
# * the outlier is 0-32 and 50-100

# %%
sns.countplot(y='workclass',data=df)

# %% [markdown]
# ### Observation:
# * the highest workclass is private.
# * the lowest workclass is without-pay.
# * all other enteries are below 5000.

# %%
sns.countplot(y='education',data=df)

# %% [markdown]
# ### Observation:
# * the highest no. of enteries are HS-grad
# * the lowest no. of enteries are Preschool.

# %%
sns.countplot(y='marital-status',data=df)

# %% [markdown]
# ### Observation:
# * The highest marital-status is married-civ-spouse.
# * the lowest is married-AF-spouse.

# %%
sns.countplot(y='occupation',data=df)

# %% [markdown]
# ### Observation:
# * the highest enteries lies between Prof-speciality,Craft-repair and Adm-clerical.
# * the lowest value is Armed-Forces.

# %%
sns.countplot(y='relationship',data=df)

# %% [markdown]
# ### Observation:
# * the highest no. of enteries in relationship is husband.
# * the lowest no. of enteries lies in other relative.

# %%
sns.countplot(y='race',data=df)

# %% [markdown]
# ### Observation:
# * the most no. of people are white.
# * then are black
# * there is a large difference in the white colour people and other coloured people

# %%
sns.countplot(y='gender',data=df)

# %% [markdown]
# ### Observation:
# * the most no of the people are male.
# * the least are female.

# %%
sns.countplot(y='native-country',data=df)

# %% [markdown]
# ### Observatipon:
# * the most no. of the people are from USA.

# %%
sns.countplot(y='income',data=df)

# %% [markdown]
# ### Observation :
# * the most no. of people are earning <=50k

# %%
hist_plot=df['hours-per-week'].hist(bins=10)
hist_plot.set_xlabel('hours-per-week')
hist_plot.set_ylabel('total no. of people')
# Out:
# Text(0, 0.5, 'total no. of people')

# %% [markdown]
# ### Observation:
# * About 25,000 people work 30-40 hours-per-week.
# * About 100 people work for 85 - 99 hours per week ,i.e, that is highest in the dataset

# %%
hist_plot=df['educational-num'].hist(bins=10)
hist_plot.set_xlabel('educational-num')
hist_plot.set_ylabel('total no. of people')
# Out:
# Text(0, 0.5, 'total no. of people')

# %% [markdown]
# ### Observation:
# * the highest no. of people lie between 9-10.
# * the lowest no. of people lie between 1-3.
# * the graph is not constant.

# %%
hist_plot=df['age'].hist(bins=10)
hist_plot.set_xlabel('age')
hist_plot.set_ylabel('total no. of people')
# Out:
# Text(0, 0.5, 'total no. of people')

# %% [markdown]
# ### Observation:
# * the highest no. of people lie between 40-45.
# * the lowest no. of people lie between 83-90.

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# ### Observation:
# * the diagonal graph are histogram and others are scatter graph.
# * people having larger educational num have more incomes.
# * people having larger educational num are working less.

# %%
sns.scatterplot(x=df['age'],y=df['capital-loss'],color='g')

# %% [markdown]
# ### observation:
# * the above scatter grph is not symmetric the most values are at 0 can be consider as outlier.

# %%
sns.jointplot(x='age',y='capital-loss',kind='hex',data=df,color='g')

# %% [markdown]
# ### Observation:
# * all the values lies at 0 it can be cansider as outlier.

# %%
sns.jointplot(x='educational-num',y='age',kind='hex',data=df,color='g')

# %% [markdown]
# ### Observation:
# * most of the results are from people working 40 hours per week.
# * it has the darkest hex line.

# %%
sns.jointplot(x='hours-per-week',y='educational-num',kind='hex',data=df,color='g')

# %% [markdown]
# ### Observation:
# * Most common region is from 40 to 65 hours per week (educational num 9 to 13)

# %%
sns.boxplot(y='age',x='income',data=df)

# %% [markdown]
# ### Observation:
# * the agevage age is 32(<=50k) and 45 (>50k)
# * the otliers lie from 80-90(<=50k)and 75-90(>50k)

# %%
sns.boxplot(y='hours-per-week',x='income',data=df)

# %% [markdown]
# ### Observation:
# * there are most outliers are in this case.
# * the average is 40(<=50k)and 45(>50k).

# %%
sns.boxplot(y='educational-num',x='income',data=df)

# %% [markdown]
# ### Observation:
# * there are most outliers in case of (<=50K)and less in (>50k).

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ### Observation:
# * the above graph can be seen as the matrix. Where diagnol element are 1.
# * its may be similar to pairplot.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# * the rows deleted are of 7%.
# * we got more male enteries than female.
# * most of the enteries has education no. of nine.
# * we have dataset that have ebteries from age 19-99
# * people with bachelors are getting >50k.
# * more than 1000 people are having 2 as their educational num.
# * most of th people work for private class.
# * very less people are unemployed.
# * most of the people work from 40-42 hours per week.
# * their are more enteries pof husband than than any other relation.

# %% [markdown]
# ## Column Normalization

# %%
df.describe()
# Out:
#                 age  educational-num  capital-gain  capital-loss  \
# count  45222.000000     45222.000000  45222.000000  45222.000000
# mean      38.547941        10.118460   1101.430344     88.595418
# std       13.217870         2.552881   7506.430084    404.956092
# min       17.000000         1.000000      0.000000      0.000000
# 25%       28.000000         9.000000      0.000000      0.000000
# 50%       37.000000        10.000000      0.000000      0.000000
# 75%       47.000000        13.000000      0.000000      0.000000
# max       90.000000        16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    45222.000000
# mean        40.938017
# std         12.007508
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
